# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s=df["Name"][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
len(s)
# Out:
# 10

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#give our own index to data

# %%
l=["a","b","d","o","e","l","w","f","g","r"]

# %%
s1=pd.Series(list(s),index=l)

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s1
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# d                               Heikkinen, Miss. Laina
# o         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# l                                     Moran, Mr. James
# w                              McCarthy, Mr. Timothy J
# f                       Palsson, Master. Gosta Leonard
# g    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# r                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2=s1.append(s)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_23328\2552242485.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2=s1.append(s)

# %%
s2
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# d                               Heikkinen, Miss. Laina
# o         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# l                                     Moran, Mr. James
# w                              McCarthy, Mr. Timothy J
# f                       Palsson, Master. Gosta Leonard
# g    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# r                  Nasser, Mrs. Nicholas (Adele Achem)
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# ...

# %%
s2[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2["e"]
# Out:
# 'Allen, Mr. William Henry'

# %%
s4=pd.Series([3,4,5,6],index=[2,4,6,1])

# %%
s4
# Out:
# 2    3
# 4    4
# 6    5
# 1    6
# dtype: int64

# %%
s5=pd.Series([34,456,567,689],index=[9,4,6,5])

# %%
s5
# Out:
# 9     34
# 4    456
# 6    567
# 5    689
# dtype: int64

# %%
s6=s4.append(s5)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22124\884104408.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s6=s4.append(s5)

# %%
s6
# Out:
# 2      3
# 4      4
# 6      5
# 1      6
# 9     34
# 4    456
# 6    567
# 5    689
# dtype: int64

# %%
s6[4]
# Out:
# 4      4
# 4    456
# dtype: int64

# %%
s6[0:5]
# Out:
# 2     3
# 4     4
# 6     5
# 1     6
# 9    34
# dtype: int64

# %%
s4
# Out:
# 2    3
# 4    4
# 6    5
# 1    6
# dtype: int64

# %%
s5
# Out:
# 9     34
# 4    456
# 6    567
# 5    689
# dtype: int64

# %%
s4*s5
# Out:
# 1       NaN
# 2       NaN
# 4    1824.0
# 5       NaN
# 6    2835.0
# 9       NaN
# dtype: float64

# %% [markdown]
# # part4

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#delete columns or rows

# %%
df.drop("PassengerId",axis=1) #this will not  drop permanently
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop("PassengerId",axis=1,inplace=True) #this will drop permanent

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d={"key1":[3,4,5,6,7],
   "key2":[5,6,7,8,9],
   "key3":[4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     9     8

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df1.dropna()#not permanent
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna(inplace=True) #pemanent

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna(axis=1,inplace=True)#axis is 1 i.e.it work for column

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.fillna("kevin")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
g=df.groupby("Survived")

# %%
g

# %%
g.sum()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_25280\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            667   8219.67    162    159  16551.2294

# %%
g.mean()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_25280\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
g1=df.groupby("Pclass")

# %%
g1

# %%
g1.sum()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_25280\2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            136  7111.42     90     77  18177.4125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.max().T
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_25280\2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
df5=df[["Name","Survived","Pclass"]][0:5]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df6=df[["Name","Survived","Pclass"]][5:10]

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
df7=pd.concat([df5,df6],axis=1)

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 4                           Allen, Mr. William Henry       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
df7.fillna("kevin")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 4                           Allen, Mr. William Henry      0.0    3.0
# 5                                              kevin    kevin  kevin
# 6                                              kevin    kevin  kevin
# 7                                              kevin    kevin  kevin
# 8                                              kevin    kevin  kevin
# 9                                              kevin    kevin  kevin
#
#                                                 Name Survived Pclass
# 0                                              kevin    kevin  kevin
# 1                                              kevin    kevin  kevin
# ...

# %%
data1=pd.DataFrame({"key1":[1,2,3,4,5],
                   "key2":[6,7,8,9,0],
                   "key3":[4,6,7,1,2]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6     4
# 1     2     7     6
# 2     3     8     7
# 3     4     9     1
# 4     5     0     2

# %%
data2=pd.DataFrame({"key1":[1,2,3,4,5],
                   "key4":[0,7,8,9,0],
                   "key5":[4,4,7,2,2]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     0     4
# 1     2     7     4
# 2     3     8     7
# 3     4     9     2
# 4     5     0     2

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     4     0     4
# 1     2     7     6     7     4
# 2     3     8     7     8     7
# 3     4     9     1     9     2
# 4     5     0     2     0     2

# %%
pd.merge(data1,data2,how="left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     4     0     4
# 1     2     7     6     7     4
# 2     3     8     7     8     7
# 3     4     9     1     9     2
# 4     5     0     2     0     2

# %%
pd.merge(data1,data2,how="outer",on="key1")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     4     0     4
# 1     2     7     6     7     4
# 2     3     8     7     8     7
# 3     4     9     1     9     2
# 4     5     0     2     0     2

# %%
pd.merge(data1,data2,how="cross")
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     6     4       1     0     4
# 1        1     6     4       2     7     4
# 2        1     6     4       3     8     7
# 3        1     6     4       4     9     2
# 4        1     6     4       5     0     2
# 5        2     7     6       1     0     4
# 6        2     7     6       2     7     4
# 7        2     7     6       3     8     7
# 8        2     7     6       4     9     2
# 9        2     7     6       5     0     2
# 10       3     8     7       1     0     4
# 11       3     8     7       2     7     4
# 12       3     8     7       3     8     7
# 13       3     8     7       4     9     2
# 14       3     8     7       5     0     2
# 15       4     9     1       1     0     4
# 16       4     9     1       2     7     4
# 17       4     9     1       3     8     7
# 18       4     9     1       4     9     2
# 19       4     9     1       5     0     2
# 20       5     0     2       1     0     4
# ...

# %%
data1=pd.DataFrame({"key1":[1,2,3,4,5],
                   "key2":[5,7,3,9,0],
                   "key3":[4,6,7,1,2]},
                   index=["a","b","c","d","e"]
)

# %%
data2=pd.DataFrame({"key4":[1,2,3,4,5],
                   "key5":[5,7,3,9,0],
                   "key6":[4,4,7,2,2]},
                  index=["a","g","c","i","j"]
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     5     4
# b     2     7     6
# c     3     3     7
# d     4     9     1
# e     5     0     2

# %%
data2
# Out:
#    key4  key5  key6
# a     1     5     4
# g     2     7     4
# c     3     3     7
# i     4     9     2
# j     5     0     2

# %%
data1.join(data2,how="inner")
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     5     4     1     5     4
# c     3     3     7     3     3     7

# %%
#merge work on the columns but join work on the index

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df["Fare_INR"]=df["Fare"].apply(lambda x:x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3  4248.000
# 4   644.000

# %%
def euro_inr(x):
    return x*80

df["Fare_INR"]=df["Fare"].apply(euro_inr)

# %%
df["Fare_INR"]
# Out:
# 0       580.000
# 1      5702.664
# 2       634.000
# 3      4248.000
# 4       644.000
#          ...
# 886    1040.000
# 887    2400.000
# 888    1876.000
# 889    2400.000
# 890     620.000
# Name: Fare_INR, Length: 891, dtype: float64

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3  4248.000
# 4   644.000

# %%
df["name_len"]=df["Name"].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Fare_INR  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# ...

# %% [markdown]
# # part5

# %%
import pandas as pd

# %%
data={"a":[1,2,3,4],
     "b":[4,5,6,7],
     "c":["sudh","kirti","jitesh","golla"]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   kirti
# 2  3  6  jitesh
# 3  4  7   golla

# %%
df.set_index("a")
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   kirti
# 3  6  jitesh
# 4  7   golla

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   kirti
# 2  3  6  jitesh
# 3  4  7   golla

# %%
df.reset_index()
# Out:
#    index  a  b       c
# 0      0  1  4    sudh
# 1      1  2  5   kirti
# 2      2  3  6  jitesh
# 3      3  4  7   golla

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   kirti
# 2  3  6  jitesh
# 3  4  7   golla

# %%
data={"a":[1,2,3,4],
     "b":[4,5,6,7],
     "c":["sudh","kirti","jitesh","golla"]}
df1=pd.DataFrame(data,index=["a","b","c","d"])

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   kirti
# c  3  6  jitesh
# d  4  7   golla

# %%
df1.reindex(["b","d","a","c"])
# Out:
#    a  b       c
# b  2  5   kirti
# d  4  7   golla
# a  1  4    sudh
# c  3  6  jitesh

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   kirti
# c  3  6  jitesh
# d  4  7   golla

# %%
for i,j in df1.iterrows():
    print(i,j)
# Out:
# a a       1
# b       4
# c    sudh
# Name: a, dtype: object
# b a        2
# b        5
# c    kirti
# Name: b, dtype: object
# c a         3
# b         6
# c    jitesh
# Name: c, dtype: object
# d a        4
# b        7
# c    golla
# Name: d, dtype: object

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   kirti
# c  3  6  jitesh
# d  4  7   golla

# %%
for i in df1.iteritems():
    print(i)
# Out:
# ('a', a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64)
# ('b', a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64)
# ('c', a      sudh
# b     kirti
# c    jitesh
# d     golla
# Name: c, dtype: object)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8060\549805685.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i in df1.iteritems():

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   kirti
# c  3  6  jitesh
# d  4  7   golla

# %%
df1["a"]
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64

# %%
[i for i in df1["a"]]
# Out:
# [1, 2, 3, 4]

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   kirti
# c  3  6  jitesh
# d  4  7   golla

# %%
def test(x):
    return x.sum()
df1.apply(test)
# Out:
# a                      10
# b                      22
# c    sudhkirtijiteshgolla
# dtype: object

# %%
df2=df1[["a","b"]]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x:x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   kirti
# c  3  6  jitesh
# d  4  7   golla

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   kirti
# 2  3  6  jitesh
# 3  4  7   golla

# %%
df.sort_values("c")
# Out:
#    a  b       c
# 3  4  7   golla
# 2  3  6  jitesh
# 1  2  5   kirti
# 0  1  4    sudh

# %%
df.sort_index(ascending=False)
# Out:
#    a  b       c
# 3  4  7   golla
# 2  3  6  jitesh
# 1  2  5   kirti
# 0  1  4    sudh

# %%
pd.set_option("display.max_colwidth",200)
df3=pd.DataFrame({"Desc":["tyyi jhsuyerkj gdsufyerhfs hgutiyhmgsn ngfdsutyirhmfnmjritukrfn ghy h h j dgterhnbm","my name is kirti","i am a student"]})

# %%
df3
# Out:
#                                                                                   Desc
# 0  tyyi jhsuyerkj gdsufyerhfs hgutiyhmgsn ngfdsutyirhmfnmjritukrfn ghy h h j dgterhnbm
# 1                                                                     my name is kirti
# 2                                                                       i am a student

# %%
df3["len"]=df3.apply(len)

# %%
df3
# Out:
#                                                                                   Desc  \
# 0  tyyi jhsuyerkj gdsufyerhfs hgutiyhmgsn ngfdsutyirhmfnmjritukrfn ghy h h j dgterhnbm
# 1                                                                     my name is kirti
# 2                                                                       i am a student
#
#    len
# 0  NaN
# 1  NaN
# 2  NaN

# %%
df3["word_count"]=df3["Desc"].apply(lambda x:len(x.split()))

# %%
df3
# Out:
#                                                                                   Desc  \
# 0  tyyi jhsuyerkj gdsufyerhfs hgutiyhmgsn ngfdsutyirhmfnmjritukrfn ghy h h j dgterhnbm
# 1                                                                     my name is kirti
# 2                                                                       i am a student
#
#    len  word_count
# 0  NaN          10
# 1  NaN           4
# 2  NaN           4

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   kirti
# 2  3  6  jitesh
# 3  4  7   golla

# %%
df["a"].mean()
# Out:
# 2.5

# %%
df["a"].median()
# Out:
# 2.5

# %%
df["a"].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df["a"].std()
# Out:
# 1.2909944487358056

# %%
df["a"].sum()
# Out:
# 10

# %%
df["a"].max()
# Out:
# 4

# %%
df["a"].var()
# Out:
# 1.6666666666666667

# %%
#python pandas:window function
df4=pd.DataFrame({"a":[3,4,5,2,1,3,4,5,6]})

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4["a"].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df4["a"].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4["a"].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
#we can apply any function like sum ,max,min and this process is called windowing

# %%
df4["a"].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %%
#python pandas=date functionality
date=pd.date_range(start="2023-04-23",end="2023-06-5")

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date=pd.DataFrame({"date":date})

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# 5  2023-04-28
# 6  2023-04-29
# 7  2023-04-30
# 8  2023-05-01
# 9  2023-05-02
# 10 2023-05-03
# 11 2023-05-04
# 12 2023-05-05
# 13 2023-05-06
# 14 2023-05-07
# 15 2023-05-08
# 16 2023-05-09
# 17 2023-05-10
# 18 2023-05-11
# 19 2023-05-12
# 20 2023-05-13
# 21 2023-05-14
# 22 2023-05-15
# 23 2023-05-16
# 24 2023-05-17
# 25 2023-05-18
# 26 2023-05-19
# 27 2023-05-20
# 28 2023-05-21
# 29 2023-05-22
# 30 2023-05-23
# 31 2023-05-24
# 32 2023-05-25
# 33 2023-05-26
# 34 2023-05-27
# 35 2023-05-28
# 36 2023-05-29
# 37 2023-05-30
# 38 2023-05-31
# 39 2023-06-01
# 40 2023-06-02
# 41 2023-06-03
# 42 2023-06-04
# 43 2023-06-05

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df7=pd.DataFrame({"date":["2023-04-8","2020-09-5"]})

# %%
df7
# Out:
#         date
# 0  2023-04-8
# 1  2020-09-5

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7["updated_date"]=pd.to_datetime(df7["date"])

# %%
df7
# Out:
#         date updated_date
# 0  2023-04-8   2023-04-08
# 1  2020-09-5   2020-09-05

# %%
df7.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df7["year"]=df7["updated_date"].dt.year

# %%
df7
# Out:
#         date updated_date  year
# 0  2023-04-8   2023-04-08  2023
# 1  2020-09-5   2020-09-05  2020

# %%
#time delta:delta helps to sum 
pd.Timedelta(days=1,hours=4,minutes=56)
# Out:
# Timedelta('1 days 04:56:00')

# %%
dt=pd.to_datetime("2023-09-7")

# %%
td=pd.Timedelta(days=1)

# %%
dt+td
# Out:
# Timestamp('2023-09-08 00:00:00')

# %%
#catogorical data

# %%
data=["kevin","lalit","pinky","matto"]

# %%
cat=pd.Categorical(data)

# %%
cat.value_counts()
# Out:
# kevin    1
# lalit    1
# matto    1
# pinky    1
# dtype: int64

# %%
#visulaliazation

# %%
d=pd.Series([1,2,3,3,5,5,7])

# %%
d.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame({"a":[3,4,5,6,7],
                "b":[4,5,6,7,8]})

# %%
df.plot(x="a",y="b")
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x="a",y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>
